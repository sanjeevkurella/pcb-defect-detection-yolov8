# %%
from google.colab import drive
drive.mount('aidefect.zip')
# Out:
# Mounted at aidefect.zip

# %%
# %cd /content
# !ls
# Out:
# /content
# aidefect.zip  sample_data

# %%
# %cd /content/aidefect.zip/MyDrive
# !ls
# Out:
# /content/aidefect.zip/MyDrive
#  24BEC0149.pdf
# '24BEC0149_Sanjeev Kurella.pdf'
#  aidefect.zip
# 'Circular - NPTEL Courses permitted for credit transfer_Jan 2025.pdf'
#  Classroom
# 'Colab Notebooks'
# 'DA 3 programs.docx'
#  DS24F2009228.pdf
# 'Enrollment form 24 - 25.pdf'
# 'FINAL CODE.gdoc'
#  FundamentalsofSmithchart-1.pdf
# 'Matching and Tuning.pdf'
#  Module-5A-TL-Lossless.pdf
# 'MPMC Lab Programs.rar'
# 'nptel payment.pdf'
# 'Pan card.pdf'
# 'PAN Self Attested (1).pdf'
# 'PAN Self Attested.pdf'
# 'Program 30 (1.10.24-2).py'
# 'Program 35 (22.10.24-1).py'
#  runs
# 'Sanjeev Aadhar Card 951185612534.pdf'
# 'Screenshot 2026-01-25 231732.png'
#  task2.docx
#  VID-20250917-WA0004_2.mp4
# 'Wells forgo Tech talk shortlist.xlsx'
# 'WhatsApp Image 2025-04-08 at 18.39.53_1b53edea.jpg'
# 'Wild Life Ecology_copy.pdf'
#  WS-2018-19-ECE2004-LECTURE-MODULE-1.pdf
#  yolo26n.pt
#  yolov8n.pt

# %%
# %cd /content/aidefect.zip/MyDrive
# Out:
# /content/aidefect.zip/MyDrive

# %%
import zipfile, os

os.makedirs("/content/pcb_data", exist_ok=True)

with zipfile.ZipFile("aidefect.zip", "r") as z:
    z.extractall("/content/pcb_data")

print("DATASET EXTRACTED SUCCESSFULLY")
# Out:
# DATASET EXTRACTED SUCCESSFULLY

# %%
# !ls /content/pcb_data
# Out:
# data.yaml  README.dataset.txt  README.roboflow.txt  train  valid

# %%
# !pip install -q ultralytics
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 39.9 MB/s eta 0:00:00

# %%
from ultralytics import YOLO
print("YOLOv8 READY")
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.
# YOLOv8 READY

# %%
from ultralytics import YOLO

model = YOLO("yolov8n.pt")

model.train(
    data="/content/pcb_data/data.yaml",
    epochs=25,
    imgsz=640,
    batch=16,
    device=0
)
# Out:
# Ultralytics 8.4.18 🚀 Python-3.12.12 torch-2.10.0+cu128 CUDA:0 (Tesla T4, 14913MiB)
# ...

# %%
# !mkdir -p /content/drive/MyDrive/pcb_model
# !cp runs/detect/train/weights/best.pt /content/drive/MyDrive/pcb_model/best.pt
# !cp runs/detect/train/weights/last.pt /content/drive/MyDrive/pcb_model/last.pt

print("best.pt and last.pt SAVED TO DRIVE")
# Out:
# best.pt and last.pt SAVED TO DRIVE

# %%
from ultralytics import YOLO

model = YOLO("/content/drive/MyDrive/pcb_model/best.pt")
print("Model loaded successfully")
# Out:
# Model loaded successfully

# %%
results = model("/content/pcb_data/valid/images", conf=0.4, save=True)
print("Inference completed")
# Out:
# WARNING ⚠️
# Inference results will accumulate in RAM unless `stream=True` is passed, which can cause out-of-memory errors for large
# sources or long-running streams and videos. See https://docs.ultralytics.com/modes/predict/ for help.
#
# Example:
#     results = model(source=..., stream=True)  # generator of Results objects
#     for r in results:
#         boxes = r.boxes  # Boxes object for bbox outputs
#         masks = r.masks  # Masks object for segment masks outputs
#         probs = r.probs  # Class probabilities for classification outputs
#
# image 1/2616 /content/pcb_data/valid/images/l_light_01_missing_hole_01_2_600_jpg.rf.ae25400cca1d49476000bc42b99a47ee.jpg: 640x640 2 missing_holes, 8.3ms
# image 2/2616 /content/pcb_data/valid/images/l_light_01_missing_hole_02_1_600_jpg.rf.e7bd447a2ee2fb10f301f08b8c815162.jpg: 640x640 2 missing_holes, 7.2ms
# ...
